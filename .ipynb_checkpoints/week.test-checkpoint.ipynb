# %%
#Q1. Which of the following is the correct syntax of an if statement in Python?
#a) if (x > y)
#b) if x > y:
#c) if x > y then:
#d) if: x > y

# %% [markdown]
# - Section A – Multiple Choice Questions (10 Marks)

# %%
#Q1. Which of the following is the correct syntax of an if statement in Python?
#a) if (x > y)
#b) if x > y:
#c) if x > y then:
#d) if: x > y

# Ans => " B = x > y :"

# %%
#Q2. What is the output of the following code?
#a = 10
#b = 5
#if a < b:
#print("Smaller")
#else:
#print("Greater")
#a) Smaller
#b) Greater
#c) Error
#d) None
a = 10
b = 5
if a < b :
  print("Smaller")
else :
  print("Greater")
    
#Ans => B = Greater
# Out:
# Greater

# %%
#Q3. Which of the following values will be considered False in Python?
#a) 1
#b) -1
#c) 0
#d) 10

# Ans => c = 0

# %%
#Q4. What will be the output?
#num = 7
#if num % 2 == 0:
#print("Even")
#else:
#print("Odd")
#a) Even
#b) Odd
#c) Error
#d) None
num = 7
if num%2 == 0 :
  print("Even")
else:
  print("Odd")

#print => B =odd
# Out:
# Odd

# %%
#Q5. Which operator is used for equality checking in Python?
#a) =
#b) ==
#c) ===
#d) !=

# Ans => B = "=="
