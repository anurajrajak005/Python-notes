# %%
#Q1. Which of the following is the correct syntax of an if statement in Python?
#a) if (x > y)
#b) if x > y:
#c) if x > y then:
#d) if: x > y

# %% [markdown]
# - Section A – Multiple Choice Questions (10 Marks)

# %%
#Q1. Which of the following is the correct syntax of an if statement in Python?
#a) if (x > y)
#b) if x > y:
#c) if x > y then:
#d) if: x > y

# Ans => " B = x > y :"

# %%
#Q2. What is the output of the following code?
#a = 10
#b = 5
#if a < b:
#print("Smaller")
#else:
#print("Greater")
#a) Smaller
#b) Greater
#c) Error
#d) None
a = 10
b = 5
if a < b :
  print("Smaller")
else :
  print("Greater")
    
#Ans => B = Greater
# Out:
# Greater

# %%
#Q3. Which of the following values will be considered False in Python?
#a) 1
#b) -1
#c) 0
#d) 10

# Ans => c = 0

# %%
#Q4. What will be the output?
#num = 7
#if num % 2 == 0:
#print("Even")
#else:
#print("Odd")
#a) Even
#b) Odd
#c) Error
#d) None
num = 7
if num%2 == 0 :
  print("Even")
else:
  print("Odd")

#print => B =odd
# Out:
# Odd

# %%
#Q5. Which operator is used for equality checking in Python?
#a) =
#b) ==
#c) ===
#d) !=

# Ans => B = "=="

# %%
#Q6. What will be printed?
#x = 5
#y = 5
#if x != y:
#print("Not Equal")
#else:
#print("Equal")
#a) Not Equal
#b) Equal
#c) Error
#d) None
x = 5
y = 5
if x!=y:
  print("Not Equal")
else:
  print("Equal")
#Ans => B = Equal
# Out:
# Equal

# %%
#Q7. Which statement is true about Python if-else?
#a) Python supports switch statement.
#b) elif is used for multiple conditions.
#c) else if is valid in Python.
#d) Only one if is allowed.

# %%
#Q8. Output of the following code:
#x = 0
#if x:
#print("Yes")
#else:
#print("No")

#a) Yes
#b) No
#c) Error
#d) None
x = 0
if x:
   print("Yes")
else:
  print("No")


#Ans => B = "No"
# Out:
# No

# %%
#Q9. Which of the following will print “Hello”?
#a)
#if True:
#print("Hello")
#b)
#if False:
#print("Hello")
#c) Both a and b
#d) None
# -- Ans => A

# %%
#Q10. What will be printed?
#a = 20
#b = 15
#if a > b and b > 10:
#print("Condition True")
#else:
#print("Condition False")
#a) Condition True
#b) Condition False
#c) Error
#d) None
a = 20
b = 15
if a  < b and b < 15 :
  print("condition True")
else:
  print("condition False")
# Out:
# condition False

# %% [markdown]
# - Section B – Intermediate Questions (30 Marks)

# %%
#Q11. Write a Python program to check whether a number is positive, negative, or zero using if - elif - else
number = int(input("Enter the number "))
if number > 0 :
  print("Postive number")
elif number == 0:
  print("Zero")
else:
  print("Negative number")
# Out:
# Enter the number  0
# Zero

# %%
#Q12. Write a program to input three numbers and print the largest number using conditional statements.
a = int(input("Enter the largest number"))
b = int(input("Enter the largest number"))
c = int(input("Enter the largest number"))
# Out:
# Enter the largest number 4
# Enter the largest number 5
# Enter the largest number 55

# %%
#Q13. A company gives bonus based on salary:
# If salary > 50,000 → 10% bonus
# If 30,000 ≤ salary ≤ 50,000 → 7% bonus
# Else → 5% bonus
#Write a program to input salary and calculate net salary after bonus.

# %%
#Q14. A shop gives discounts based on purchase amount:
# If amount > 5000 → 20% discount
# If 3000 ≤ amount ≤ 5000 → 10% discount
# Else → 5% discount
#Write a Python program to input amount and calculate the final amount after discount.

# %%
#Q15. Write a Python program to check whether a given year is a leap year or not.
