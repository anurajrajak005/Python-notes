# %% [raw]
# ##### Lec = 1 : * *

# %% [markdown]
# Hey i am starded in python in CumpusX

# %% [markdown]
# #### Lec = 1 : *print is Build-Function*

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(6)
# Out:
# 6

# %%
print(False)
# Out:
# False

# %%
print("India","Pakistan","Nepal","Srilanka")
# Out:
# India Pakistan Nepal Srilanka

# %%
print("Anuraj",5,True)
# Out:
# Anuraj 5 True

# %%
print("India","Pakistan","Nepal","Srilanka",sep="-")
# Out:
# India-Pakistan-Nepal-Srilanka

# %%
print("India","Pakistan","Nepal","Srilanka",sep="/")
# Out:
# India/Pakistan/Nepal/Srilanka

# %%
print("India","Pakistan","Nepal","Srilanka",sep="|")
# Out:
# India|Pakistan|Nepal|Srilanka

# %%
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Hello",end=" ")
print("World")
# Out:
# Hello World

# %%
print("Anuraj",end=" ")
print("Rajak")
# Out:
# Anuraj Rajak

# %% [raw]
# print()+then shift+ tab

# %% [markdown]
# ##### Lec = 2 : *Data type*

# %% [markdown]
# ### Python support 3 categories of data types
# #### 3. user-defind Class
# ##### 1. *Basic Types (Integer , Float , Complex , Boolean  and string).*
# ##### 2. *container Types (List , Tuples , Sets and Dictionary).*
# ##### 3. *user-defind Class.*

# %% [markdown]
# - #### 1. *integer*

# %%
print(4)
# Out:
# 4

# %%
print('le3O9')
# Out:
# le3O9

# %% [markdown]
# - #### 2. *Float*

# %%
print(4.5)
# Out:
# 4.5

# %%
print(1.7e308)
# Out:
# 1.7e+308

# %% [markdown]
# - #### 3. *Boolean*

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# - #### 4. *Complex*

# %%
print(4+5j)
# Out:
# (4+5j)

# %% [markdown]
# - #### 5. *String*

# %%
print('Bhopal')
print("Bhopal")
# Out:
# Bhopal
# Bhopal

# %% [markdown]
# ### Container Types Function

# %% [markdown]
# - *List*

# %%
print([1,2,3,3,4,4,4,5,5,6,6,67,7])
# Out:
# [1, 2, 3, 3, 4, 4, 4, 5, 5, 6, 6, 67, 7]

# %% [markdown]
# - *Tuple*

# %%
print(1,2,3,4,5,56,6,)
# Out:
# 1 2 3 4 5 56 6

# %%
print((1,2,3,4,5,56,6,))
# Out:
# (1, 2, 3, 4, 5, 56, 6)

# %% [markdown]
# - *Sets*

# %%
print({1,23,33,99,378,9})
# Out:
# {1, 33, 99, 23, 9, 378}

# %% [markdown]
# - *Dict*

# %%
print({"Nitesh", 30, "male"})
# Out:
# {'male', 30, 'Nitesh'}

# %%
print({'Name':"Nitesh", "Age":30 , "Gender":'male'})
# Out:
# {'Name': 'Nitesh', 'Age': 30, 'Gender': 'male'}

# %%
print({
    "name":"Anuraj Rajak",
    "Age":21,
    "Gender": "Male",
    "Contract": 9669539437,
    "City": "Bhopal",
    "States": "MP"
})
# Out:
# {'name': 'Anuraj Rajak', 'Age': 21, 'Gender': 'Male', 'Contract': 9669539437, 'City': 'Bhopal', 'States': 'MP'}

# %% [markdown]
# ##### Lec = 3 : *Comments*

# %% [markdown]
# ##### *Comments can be used to explain Python code.*
# ##### *Comments can be used to make the code more readable.*
# ##### *Comments can be used to prevent execution when testing code.*

# %% [markdown]
# - #### *Creating a Comment.*
# - *Comments starts with a #, and Python will ignore them*

# %%
#This is a comment
print("Hello, World!")
# Out:
# Hello, World!

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")

# %%
# print("Anuraj")

# %% [raw]
# # is a comments and create a comments in select a data and press a {Ctrl + /} the data is convart in comments

# %% [markdown]
# - *Comments can be placed at the end of a line, and Python will ignore the rest of the line.*

# %%
print("Hello, World!") #This is a comment
# Out:
# Hello, World!

# %%
# print('john')
# print("Ram")

# %% [markdown]
# ##### Lec = 4 : *Variables-python*

# %% [markdown]
# #### Variables =  *variable is a named container used to store data values in computer memory.*

# %%
name =  "Anuraj" # Anuraj is variables

# %%
print(name)
# Out:
# Anuraj

# %%
name = "Hello World"
print(name)
# Out:
# Hello World

# %%
# no variable Declaration in python

# %% [raw]
# Dynamic Typing
# static typing

# %%
# python me sirf dynamic typing hota hai 
    # Dynamic typing ke ex- PHp and python

# %%
print(name)
# Out:
# Hello World

# %%
name = 4
print(name)
# Out:
# 4

# %%
name = True
print(name)
# Out:
# True

# %% [raw]
# python me bar-bar change kar sakte hai datatype  and yese data type of dynamic typing bolte hai

# %% [raw]
# python me sirf dynamic typing hota hai
# and st

# %% [markdown]
# # ![image.png](attachment:852fbc8b-5bad-4858-b2bc-b69abd7004aa.png)

# %% [markdown]
# #### *Basic Data*
# ##### - TypesVariables store references to various built-in object types.

# %%
x, y, z = 1, 2.5, "Three"

# %%
x = y = z = 100

# %%
a, b = 5, 10
a, b = b, a  # a becomes 10, b becomes 5

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
