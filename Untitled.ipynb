# %% [markdown]
# ### Python Introduction

# %% [markdown]
# #### Python is a high-level programming language known for its simple and readable syntax. It has the following features:
#
# ##### > Allows writing clean code with fewer lines.
# ##### > Supports multiple programming paradigms including object-oriented, functional and procedural programming.
# ##### > Widely used in web development, automation, data analysis, artificial intelligence and many other fields.
# ##### > Dynamically typed and has automatic garbage collection

# %% [markdown]
# ##### Basic Python Introduction — Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.

# %%
A = 10
name = "Anuraj"
print(A)
print(name)
# Out:
# 10
# Anuraj

# %% [markdown]
# ## Data Types — Built-in categories of values:
#
#
# ##### int (whole numbers), float (decimals), complex (numbers with imaginary parts)
# ##### str (text), bool (True/False)
# ##### list, tuple, set, dict

# %% [markdown]
# ##### age = input("Enter age: ")  # string
# print("Your age is", age)

# %% [markdown]
# * ## Statements
#   #####  A computer program is a list of "instructions" to be "executed" by a computer.  In a programming language, these programming instructions are called statements.

# %%
print("Python is fun!")
# Out:
# Python is fun!

# %% [markdown]
#  * ### Most Python programs contain many statements.
#
#    - The statements are executed one by one, in the same order as they are written:

# %%
#Example
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %% [markdown]
# * ### Python Syntax Code Challenge
# *   Test your understanding of Python statements by completing a small coding challenge.

# %% [markdown]
# * ### Instructions
#   ##### Inside the editor, complete the following steps:
#   - Write a statement that prints "Hello World!"
#   - Write a statement that prints "Have a good day."
#   - Write a statement that prints "Learning Python is fun!"

# %% [markdown]
# * ## Python Comments
#    - Comments can be used to explain Python code.
#
#    - Comments can be used to make the code more readable.
#
#    - Comments can be used to prevent execution when testing code.
#
# *  ### Creating a Comment
#    - Comments starts with a #, and Python will ignore them:
#    - ctrl + /

# %%
print("hello world") # this is not comment a code 
# print("hello world") # this is  comment a code
# Out:
# hello world

# %% [markdown]
# * ###  Python Variables
#    - Variables are containers for storing data values.

# %%
a="jatin"
a=False
b=20
# How to find the type of data
print(type(a))
#How to find the memory address
print(id(a))
print(id(a))
#memory add hamse variable ka nikale ga bas ....
# Out:
# <class 'bool'>
# 140725765978624
# 140725765978624

# %%
a=int(input("Enter a number"))
b=int(input("Enter a number"))
c=int(input("Enter a number"))
print(a>b and a>c)
print(b>a and b>c)
print(c>a and c>b)
# Out:
# Enter a number 44
# Enter a number 4
# Enter a number 4
# True
# False
# False

# %%
a=int(input("Enter a number"))
b=int(input("Enter a number"))
c=int(input("Enter a number"))

print(a>b and a>c)
print(b>a and b>c)
print(c>b and c>a)
# Out:
# Enter a number 44
# Enter a number 4
# Enter a number 4
# True
# False
# False

# %%
# how to find the memory size
import sys
a = 10
print(sys.getsizeof(a))
# Out:
# 28

# %%
a = 10
num=input("Enter a Number")
print("The given number is ",a)
# Out:
# Enter a Number 4
# The given number is  10

# %%
a = 10
num=input("Enter a Number")
print("The given number is ",num)
# Out:
# Enter a Number 4
# The given number is  4

# %%
a=input("Enter a number")
b=input("Enter a number")
print(a+b)
#add the function of a 5+5= 55
# Out:
# Enter a number 4
# Enter a number 4
# 44

# %%
a=int(input("Enter a number"))
b=int(input("Enter a number"))
print(a+b)
#add the function of a 5+5= 10
# Out:
# Enter a number 4
# Enter a number 4
# 8

# %%
a=20
b=40
print(a+b)    #Addition
print(a-b)    #subtraction
print(a*b)    #Multiplication
print(a/b)    #Division
print(a//b)   #Floor division
print(a%b)    #Modulus
print(a**b)   #Exponentiation
# Out:
# 60
# -20
# 800
# 0.5
# 0
# 20
# 10995116277760000000000000000000000000000000000000000

# %%
side = int(input("Enter a side"))
print(side*side)
#area of rectangle
# Out:
# Enter a side 4
# 16

# %%
base = float(input("Enter then base of the triangle"))
height = float(input("Enter then height of the triangle"))
area = 0.5 * base * height
print("The area of the triangle is", area)
# Out:
# Enter then base of the triangle 4
# Enter then height of the triangle 4
# The area of the triangle is 8.0

# %%
radius = float(input("Enter the radius of the circle"))
pi = 3.14
area = pi*(radius**2)
print("The area of the radius circle is", area)
# Out:
# Enter the radius of the circle 4
# The area of the radius circle is 50.24

# %%
radius = float(input("Enter the radius"))
height = float(input("Enter the height"))
pi = 3.14
cylinder_volume = pi*(radius**2)*height
print("The volume of the cylinder is:", cylinder_volume)
# Out:
# Enter the radius 444
# Enter the height 44
# The volume of the cylinder is: 27236309.76

# %%
#area of cube
area = int(input("surface area"))
A = 6*(area**2)
print(A)
# Out:
# surface area 6
# 216

# %%
#Fahrenheit to celsius
celsius= int(input("Enter the calsius"))
Fahrenheit = (celsius*1.8)+32
print("Fahrenheit to celsius", Fahrenheit)
# Out:
# Enter the calsius 212
# Fahrenheit to celsius 413.6

# %%
# Celsius to Fahrenheit Conversion
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9 / 5) + 32
print("Temperature in Fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius:  413.6
# Temperature in Fahrenheit = 776.48

# %%
print(8<<3)
# Out:
# 64

# %%
print(64>>3)
# Out:
# 8

# %%
print(64<<4)
# Out:
# 1024

# %%
#member operator
# 1-> in
# 2 -> in not

name = "Jatin"
print('Z' in name)
print('j' not in name)
# Out:
# False
# True

# %%
#member opertar
name = "Anuraj"
print('k' in name )
print('k' not in name)
# Out:
# False
# True

# %%
#identity operatoor
# 1-> is
# 2-> is not
#mumutable int float complex string tuple
a = 20
b = 20
print(a is b)
print(id(a))
print(id(b))
# Out:
# True
# 140725766891016
# 140725766891016

# %%
# 1-> is
# 2-> is not
a = 10
b = 20
print(a is not b)
print(id(a))
print(id(b))
# Out:
# True
# 140725766890696
# 140725766891016

# %%
#even , odd
a = int(input("Enter the number"))
print("even") if a%2 == 0 else print("odd")
# Out:
# Enter the number 5
# odd

# %%
#cheack the persoon id eligiable for vote or note
age = int(input("Enter your age"))
print("Eligiable") if age>18 else print("not Eligiable")
# Out:
# Enter your age 5
# not Eligiable

# %%
#greater
# a = int(input("Enter a number"))
# b = int(input("Enter a number"))
a = int(input("Enter a number"))
b = int(input("Enter a number"))
print(a, "is a greatest") if a>b else print(b, "is a greatest")
# Out:
# Enter a number 55
# Enter a number 45
# 55 is a greatest

# %%
#cheack the persoon id eligiable for vote or note
age = int(input("Enter your age"))
print("Eligiable") if age>18 else print("not Eligiable")
# Out:
# Enter your age 54
# Eligiable

# %%
#check person is pass or fail
# passing marks = 33 above
passing = int(input("Enter the marks"))
print("pass") if passing>33 else print("fail")
# Out:
# Enter the marks 6
# fail

# %%
#check the password is corret or not password "1234"
a = input("1234")
print("correct")  if a=="1234"  else print("incorrect")
#jab bhi koi cheej cmapre karte hai tab == me likte hai
# Out:
# 1234 1234
# correct

# %%
#check the number is divisible by 5 or not
number = int(input("Enter the number"))
print("yes") if number%5==0 else print("not")
# Out:
# Enter the number 25
# yes

# %%
#check the number is divisible by  7 or not
number = int(input("Enter the number"))
print("yes") if number%7==0 else print("no")
# Out:
# Enter the number 21
# yes

# %%
#check the number is postive or negative
nums = int(input("Enter any value"))
if (0<nums) : print(nums,"is postive number")
else:
   print(nums, "is negative number")
# Out:
# Enter any value 5
# 5 is postive number

# %%
#check the number is postive or negative
nums = int(input("Enter the number"))
print(nums,"postive") if 0<nums else print(nums, "negative")
# Out:
# Enter the number 5
# 5 postive

# %%
#check the number is above 50 or not
number = int(input("Enter the nunber"))
print("yes") if number>50 else print("not")
# Out:
# Enter the nunber 54
# yes

# %%
#check the number is between 0 - 50 or not
number = int(input("Enter the number"))
print("yes") if number>0 and number<50 else print("not")
# Out:
# Enter the number 5
# yes

# %%
#check the number is between 51 to 101 or not
number = int(input("Enter the number"))
print(number, "yes 51- 101 between number") if number>51 and number<101 else print(number, "no 51- 101 between number")
# Out:
# Enter the number 5
# 5 no 51- 101 between number

# %%
#check the number is divisible by 2 & 4 or not
number = int(input("Enter the number"))
print("yes") if number%2==0 and number%4==0 else print("not")
# Out:
# Enter the number 56
# yes

# %%
# check the number is above 50 and divisible by 5 or not
number = int(input("Enter a number"))
print("yes") if 50%5 else print("not")
# Out:
# Enter a number 51
# not

# %%
#checkthe username is correct ar not username user@gmail.com
a = input("user@gmail.com")
print("correct")  if a=="user@gmail.com"  else print("incorrect")
# Out:
# user@gmail.com 5
# incorrect

# %%
#check the password is correct or not password 1234
a = input("1234")
print("correct")  if a=="1234"  else print("incorrect")
# Out:
# 1234 1234
# correct

# %%
#check the username and password is correct or not password 1234 username user@gmail.com
username = input("user@gmail.com")
password = input("1234")
print("correct") if username=="user@gmail.com" and password=="1234" else print("incorrect")
# Out:
# user@gmail.com 5
# 1234 1234
# incorrect

# %%
#check the username and password is correct or not number = 9669539437 email = anurajrajak112@gmail.com pincode
number = input("9669539437")
email = input("anurajrajak112@gmail.com")
pincode = input("462044")
print("correct") if number=="9669539437" and email=="anurajrajak112@gmail.com" and pincode=="462044" else print("incorrect")
# Out:
# 9669539437 5
# anurajrajak112@gmail.com 4
# 462044 4
# incorrect

# %%
#check the number is a multiple of 3 or not
number = int(input("Enter the number"))
print("yes") if number%3==0 else print("not")
#multiple == divisible
# Out:
# Enter the number 4
# not

# %%
#voewl
